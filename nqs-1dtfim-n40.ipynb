# %%
import numpy as np 
import matplotlib.pyplot as plt

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/nqs-rnn/rnn_impl_tf2.py
# /kaggle/input/nqs-rnn/nqs_TrainingLoop_hyp_tf2.py
# /kaggle/input/nqs-rnn/util_v2.py
# /kaggle/input/nqs-rnn/nqs_RNNwavefunction_hyp.py

# %%
#https://www.kaggle.com/discussions/product-feedback/91185
import sys
sys.path.insert(1,'/kaggle/input/nqs-rnn/')
from nqs_TrainingLoop_hyp_tf2 import *

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
N=40
numunits = 50
Jz = np.ones(N)
Bx = 1
E_exact = -50.5694337844

# %%
if not os.path.exists('/kaggle/working/results'):
    os.mkdir('/kaggle/working/results')

# %%
#HypRNN
mE_hrnn, vE_hrnn = run_1DTFIM(numsteps = 200,cell_type = 'HypRNN', systemsize = N, num_units = numunits, 
                              Bx = Bx, numsamples = 500, learningrate=1e-2, seed = 111)
# Out:
# step: 0, loss: 0.8221168311181373, mean energy: -39.66076876074962, varE: 33.3201401664028
# step: 10, loss: -2.9073572729599846, mean energy: -48.6499371971291, varE: 6.672826460442946
# step: 20, loss: 3.7089143533615925, mean energy: -49.14779444259324, varE: 3.4560759388298674
# step: 30, loss: -0.6674193324820408, mean energy: -49.35372622618592, varE: 3.2793304769655323
# step: 40, loss: -0.6118967773471127, mean energy: -49.19981048883214, varE: 2.476708674414531
# step: 50, loss: 0.39394333805637416, mean energy: -49.3223429318269, varE: 2.6353940298826455
# step: 60, loss: 0.06367215224463507, mean energy: -49.351167917498955, varE: 2.9137396397241426
# step: 70, loss: 0.2505362059312688, mean energy: -49.31759874179856, varE: 2.842147312727372
# step: 80, loss: 0.07187373717920309, mean energy: -49.41683296632259, varE: 3.243259915717765
# step: 90, loss: -0.027361954935258836, mean energy: -49.29626552850558, varE: 2.9869545969653233
# step: 110, loss: 0.029637204412836127, mean energy: -49.32743138050231, varE: 2.7651836994167587
# step: 120, loss: -0.10968854889688373, mean energy: -49.292544626947915, varE: 2.61612166836097
# step: 130, loss: 0.686770040581905, mean energy: -49.29165770109229, varE: 2.4520666926089607
# step: 140, loss: 0.8319299719173614, mean energy: -49.34090016914181, varE: 3.1791124094472445
# step: 150, loss: -0.39735013712424916, mean energy: -49.36284243502956, varE: 3.0331320987085686
# step: 170, loss: 0.44812610407950615, mean energy: -49.38643052737249, varE: 2.9362718041039835
# step: 190, loss: 0.6391897869075933, mean energy: -49.347539062808124, varE: 2.7662321475910074

# %%
#HypGRU
mE_hgru, vE_hgru = run_1DTFIM(numsteps = 200,cell_type = 'HypGRU', systemsize = N, num_units = numunits, Bx = Bx, 
                numsamples = 500, learningrate=1e-2, seed = 111)

# %%
#EuclGRU
mE_egru, vE_egru = run_1DTFIM(numsteps = 200,cell_type = 'EuclGRU', systemsize = N, num_units = numunits, Bx = Bx, 
                numsamples = 500, learningrate=1e-2, seed = 111)

# %%
#EuclRNN
mE_ernn, vE_ernn = run_1DTFIM(numsteps = 200,cell_type = 'EuclRNN', systemsize = N, num_units = numunits, Bx = Bx, 
                numsamples = 500, learningrate=1e-2, seed = 111)
