# %% [markdown]
# # 1D J1-J2: Convergence curves
#
# This notebook is part of the work arXiv:2505.22083 (https://arxiv.org/abs/2505.22083), "Hyperbolic recurrent neural network as the first type of non-Euclidean neural quantum state ansatz". Code written by HLD.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sys
sys.path.append('../../utility')
numsamples = 10000
rn = 4

# %%
Ee00 =-21.9721
Ee02 = -20.3150
Ee05 = -18.7500
Ee08 = -20.9842

# %%
fname = '../results_w_grad_clipping/'
#Unless otherwise stated, all results are obtained by using training with grad clipping by global norm of 8.0
###################################### J2 = 0.0 #######################################
mE00_75 = np.load(f'{fname}N50_J2=0.0/N50_J1=1.0|J2=0.0_EuclGRU_75_ns50_MsTrue_meanE.npy')
vE00_75 = np.load(f'{fname}N50_J2=0.0/N50_J1=1.0|J2=0.0_EuclGRU_75_ns=50_MsTrue_varE.npy')
#Use grad clipping by value [-1,1]
mEh00_60 =np.load(f'{fname}N50_J2=0.0/N50_J1=1.0|J2=0.0_HypGRU_60_id_hyp_ns50_MsTrue_meanE_gcv.npy')
vEh00_60 =np.load(f'{fname}N50_J2=0.0/N50_J1=1.0|J2=0.0_HypGRU_60_id_hyp_ns=50_MsTrue_varE_gcv.npy')

###################################### J2 = 0.2 #######################################
mE02_75 = np.load(f'{fname}N50_J2=0.2/N50_J1=1.0|J2=0.2_EuclGRU_75_ns50_MsTrue_meanE.npy')
vE02_75 = np.load(f'{fname}N50_J2=0.2/N50_J1=1.0|J2=0.2_EuclGRU_75_ns=50_MsTrue_varE.npy')
#global norm = 9.0
mEh02_75 =np.load(f'{fname}N50_J2=0.2/N50_J1=1.0|J2=0.2_HypGRU_75_id_hyp_ns50_MsTrue_meanE.npy')
vEh02_75 =np.load(f'{fname}N50_J2=0.2/N50_J1=1.0|J2=0.2_HypGRU_75_id_hyp_ns=50_MsTrue_varE.npy')

###################################### J2 = 0.5 #######################################
#Use grad clipping by value [-1,1]
mE05_75 = np.load(f'{fname}N50_J2=0.5/N50_J1=1.0|J2=0.5_EuclGRU_75_ns50_MsTrue_meanE.npy')
vE05_75 = np.load(f'{fname}N50_J2=0.5/N50_J1=1.0|J2=0.5_EuclGRU_75_ns=50_MsTrue_varE.npy')
#No grad clipping
mEh05_70 =np.load(f'{fname}N50_J2=0.5/N50_J1=1.0|J2=0.5_HypGRU_70_id_hyp_ns50_ngc_MsTrue_meanE.npy')
vEh05_70 =np.load(f'{fname}N50_J2=0.5/N50_J1=1.0|J2=0.5_HypGRU_70_id_hyp_ns=50_ngc_MsTrue_varE.npy')

###################################### J2 = 0.8 #######################################
mE08_75 = np.load(f'{fname}N50_J2=0.8/N50_J1=1.0|J2=0.8_EuclGRU_75_ns50_MsTrue_meanE.npy')
vE08_75 = np.load(f'{fname}N50_J2=0.8/N50_J1=1.0|J2=0.8_EuclGRU_75_ns=50_MsTrue_varE.npy')
mEh08_75 =np.load(f'{fname}N50_J2=0.8/N50_J1=1.0|J2=0.8_HypGRU_75_id_hyp_ns50_gn=8_MsTrue_meanE.npy')
vEh08_75 =np.load(f'{fname}N50_J2=0.8/N50_J1=1.0|J2=0.8_HypGRU_75_id_hyp_ns=50_gn=8_MsTrue_varE.npy')

# %%
#results with no gradient clipping (original results)

###################################### J2 = 0.0 #######################################
fname = '../results_no_grad_clipping/N50_J2=0.0'
mE00_75_o = np.load(f'{fname}/N50_J1=1.0|J2=0.0_EuclGRU_75_ns50_MsTrue_meanE.npy')
vE00_75_o = np.load(f'{fname}/N50_J1=1.0|J2=0.0_EuclGRU_75_ns=50_MsTrue_varE.npy')
mEh00_60_o =np.load(f'{fname}/N50_J1=1.0|J2=0.0_HypGRU_60_id_hyp_ns50_MsTrue_meanE.npy')
vEh00_60_o =np.load(f'{fname}/N50_J1=1.0|J2=0.0_HypGRU_60_id_hyp_ns=50_MsTrue_varE.npy')

###################################### J2 = 0.2 #######################################
fname = '../results_no_grad_clipping/N50_J2=0.2'
mE02_75_o = np.load(f'{fname}/N50_J1=1.0|J2=0.2_EuclGRU_75_ns50_MsTrue_meanE.npy')
vE02_75_o = np.load(f'{fname}/N50_J1=1.0|J2=0.2_EuclGRU_75_ns=50_MsTrue_varE.npy')
mEh02_75_o =np.load(f'{fname}/N50_J1=1.0|J2=0.2_HypGRU_75_id_hyp_ns50_MsTrue_meanE.npy')
vEh02_75_o =np.load(f'{fname}/N50_J1=1.0|J2=0.2_HypGRU_75_id_hyp_ns=50_MsTrue_varE.npy')

###################################### J2 = 0.5 #######################################
fname = '../results_no_grad_clipping/N50_J2=0.5'
mE05_75_o = np.load(f'{fname}/N50_J1=1.0|J2=0.5_EuclGRU_75_ns50_MsTrue_meanE.npy')
vE05_75_o = np.load(f'{fname}/N50_J1=1.0|J2=0.5_EuclGRU_75_ns=50_MsTrue_varE.npy')

mEh05_70_o =np.load(f'{fname}/N50_J1=1.0|J2=0.5_HypGRU_70_id_hyp_ns50_MsTrue_meanE.npy')
vEh05_70_o =np.load(f'{fname}/N50_J1=1.0|J2=0.5_HypGRU_70_id_hyp_ns=50_MsTrue_varE.npy')

###################################### J2 = 0.8 #######################################
fname = '../results_no_grad_clipping/N50_J2=0.8'
mE08_75_o = np.load(f'{fname}/N50_J1=1.0|J2=0.8_EuclGRU_75_ns50_MsTrue_meanE.npy')
vE08_75_o = np.load(f'{fname}/N50_J1=1.0|J2=0.8_EuclGRU_75_ns=50_MsTrue_varE.npy')
mEh08_75_o =np.load(f'{fname}/N50_J1=1.0|J2=0.8_HypGRU_75_id_hyp_ns50_MsTrue_meanE.npy')
vEh08_75_o =np.load(f'{fname}/N50_J1=1.0|J2=0.8_HypGRU_75_id_hyp_ns=50_MsTrue_varE.npy')

# %% [markdown]
# # Convergence curves

# %%
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
color_l = ['cyan', 'green', 'pink', 'purple']
def plot_res_meanE(ax, Ee, e_list, last_saved_epoch, e_names, j2, frange, legend_loc, inset = False):
    for i in range(len(e_list)):
        ax.plot(np.arange(len(e_list[i])), np.real(e_list[i]),color = color_l[i], label = e_names[i])
    ax.axvline(x=last_saved_epoch[0], ymax = 0.6, color = color_l[0], linestyle='--', linewidth=2, label='eGRU_bm')
    ax.axvline(x=last_saved_epoch[1], ymax = 0.6, color=color_l[1], linestyle='--', linewidth=2, label='hGRU_bm')
    ax.axhline(Ee, color = 'red', linestyle = 'dashed', label = 'DMRG')
    ax.set_xlabel("Epoch", fontsize = 14)
    ax.set_ylabel("Mean Energy", fontsize = 14)
    ax.set_title(f"J2={j2}",fontsize = 15)
    
    if inset:
        ax2 = inset_axes(
                parent_axes=ax,
                width="45%",
                height="35%",
                borderpad=1  # padding between parent and inset axes
            )
        for i in range(len(e_list)):
            ax2.plot(np.arange(len(e_list[i])), np.real(e_list[i]),color = color_l[i], label = e_names[i])
        ax2.axvline(x=last_saved_epoch[0], ymax = 0.7, color = color_l[0], linestyle='--', linewidth=2, label='eGRU_bm')
        ax2.axvline(x=last_saved_epoch[1], ymax = 0.7, color=color_l[1], linestyle='--', linewidth=2, label='hGRU_bm')
        ax2.axhline(Ee, color = 'red', linestyle = 'dashed', label = 'DMRG')
        ax2.axis(frange)
        ax.legend(loc='best', bbox_to_anchor=legend_loc)
    else:
        ax.legend(loc='best')

# %%
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
color_l = ['cyan', 'green',  'pink', 'purple']
def plot_res_var(ax, v_list, e_names, j2, frange, legend_loc):
    for i in range(len(v_list)):
        ax.plot(np.arange(len(v_list[i])), v_list[i],color = color_l[i], label = e_names[i])
    ax.axhline(0.0, color = 'red', linestyle = 'dashed')
    ax.set_xlabel("Epoch", fontsize = 14)
    ax.set_ylim(-5, 45)
    ax.set_ylabel("Energy variance", fontsize = 14)
    ax.set_title(f"J2={j2}",
              fontsize = 15)

    ax.legend(loc='best')

# %%
#Last saved epoch corresponding to the best model
#The matrix below has the form : (eRNN, eGRU) as columns, J2=0.0, 0.2, 0.5, 0.8 as rows
#Total training epochs is 450 for all experiments
#Data from training notebooks 
bm_gc = np.array([[384,415],[414, 447],[365,404],[405,430]])
#print(bm)
print(f'Training with gradient clipping')
print(f'For J2 = 0.0, best model for eGRU is saved at epoch {bm_gc[0,0]}/450, for hGRU is at {bm_gc[0,1]}/450')
print(f'For J2 = 0.2, best model for eGRU is saved at epoch {bm_gc[1,0]}/450, for hGRU is at {bm_gc[1,1]}/450')
print(f'For J2 = 0.5, best model for eGRU is saved at epoch {bm_gc[2,0]}/450, for hGRU is at {bm_gc[2,1]}/450')
print(f'For J2 = 0.8, best model for eGRU is saved at epoch {bm_gc[3,0]}/450, for hGRU is at {bm_gc[3,1]}/450')
print('=========================================================')
#Total training epochs is 400 for all experiments
print(f'Training with no gradient clipping')
bm_ngc = np.array([[379,336],[120, 383],[398,339],[397,376]])
#print(bm)
print(f'For J2 = 0.0, best model for eGRU is saved at epoch {bm_ngc[0,0]}/400, for hGRU is at {bm_ngc[0,1]}/400')
print(f'For J2 = 0.2, best model for eGRU is saved at epoch {bm_ngc[1,0]}/400, for hGRU is at {bm_ngc[1,1]}/400')
print(f'For J2 = 0.5, best model for eGRU is saved at epoch {bm_ngc[2,0]}/400, for hGRU is at {bm_ngc[2,1]}/400')
print(f'For J2 = 0.8, best model for eGRU is saved at epoch {bm_ngc[3,0]}/400, for hGRU is at {bm_ngc[3,1]}/400')
# Out:
# Training with gradient clipping
# For J2 = 0.0, best model for eGRU is saved at epoch 384/450, for hGRU is at 415/450
# For J2 = 0.2, best model for eGRU is saved at epoch 414/450, for hGRU is at 447/450
# For J2 = 0.5, best model for eGRU is saved at epoch 365/450, for hGRU is at 404/450
# For J2 = 0.8, best model for eGRU is saved at epoch 405/450, for hGRU is at 430/450
# ...
# Training with no gradient clipping
# For J2 = 0.0, best model for eGRU is saved at epoch 379/400, for hGRU is at 336/400
# For J2 = 0.2, best model for eGRU is saved at epoch 120/400, for hGRU is at 383/400
# For J2 = 0.5, best model for eGRU is saved at epoch 398/400, for hGRU is at 339/400
# For J2 = 0.8, best model for eGRU is saved at epoch 397/400, for hGRU is at 376/400

# %%
#NO GRADIENT CLIPPING
fig, ax = plt.subplots(2,2, figsize=(10, 10), tight_layout=True)
e_list00 = [mE00_75_o, mEh00_60_o]
e_names00 = ['eGRU_75_s50_o',  'hGRU_60_s50_o']

e_list02 = [mE02_75_o,  mEh02_75_o]
e_names02 = ['eGRU_75_s50_o', 'hGRU_75_s50_o']

e_list05 = [mE05_75_o[:-5], mEh05_70_o]
e_names05 = ['eGRU_75_s50_o', 'hGRU_70_s50_o']

e_list08 = [mE08_75_o, mEh08_75_o[:-5]]
e_names08 = ['eGRU_75_s50_o', 'hGRU_75_s50_o']

plot_res_meanE(ax[0,0], Ee00, e_list00, bm_ngc[0], e_names00, 0.0, [200,460, Ee00-0.5, Ee00+3.5], (0.15, 0.28, 0.8, 0.2))
plot_res_meanE(ax[0,1], Ee02, e_list02, bm_ngc[1], e_names02, 0.2, [200,460, Ee02-0.2, Ee02+1.5], (0.15, 0.28, 0.8, 0.2))
plot_res_meanE(ax[1,0], Ee05, e_list05, bm_ngc[2], e_names05, 0.5, [200,460,Ee05-0.2, Ee05+0.7], (0.15, 0.3, 0.8, 0.2))
plot_res_meanE(ax[1,1], Ee08, e_list08, bm_ngc[3], e_names08, 0.8, [250,460,Ee08-0.5, Ee08+4.5], (0.15, 0.3, 0.8, 0.2))

plt.suptitle('1D J1-J2: Mean energy convergence (No gradient clipping)', fontsize = 23)
plt.savefig('1D-J1-J2-N=50_no_gc.png')

# %%
color_l = ['orange', 'purple']
fig, ax = plt.subplots(2,2, figsize=(12, 12), tight_layout=True)
e_list00 = [mE00_75, mEh00_60]
e_names00 = ['eGRU_75_s50',  'hGRU_60_s50']

e_list02 = [mE02_75,  mEh02_75]
e_names02 = ['eGRU_75_s50', 'hGRU_75_s50']

e_list05 = [mE05_75, mEh05_70]
e_names05 = ['eGRU_75_s50', 'hGRU_70_s50_o']

e_list08 = [mE08_75, mEh08_75]
e_names08 = ['eGRU_75_s50', 'hGRU_75_s50']

plot_res_meanE(ax[0,0], Ee00, e_list00, bm_gc[0], e_names00, 0.0, [200,460, Ee00-0.5, Ee00+3.5], (0.15, 0.3, 0.6, 0.2), True)
plot_res_meanE(ax[0,1], Ee02, e_list02, bm_gc[1], e_names02, 0.2, [200,460, Ee02-0.2, Ee02+1.5], (0.15, 0.3, 0.6, 0.2), True)
plot_res_meanE(ax[1,0], Ee05, e_list05, bm_gc[2], e_names05, 0.5, [200,460,Ee05-0.2, Ee05+0.7], (0.15, 0.3, 0.6, 0.2), True)
plot_res_meanE(ax[1,1], Ee08, e_list08, bm_gc[3], e_names08, 0.8, [250,460,Ee08-0.5, Ee08+4.5], (0.15, 0.3, 0.8, 0.2), True)

plt.suptitle('1D J1-J2: Mean energy convergence (with gradient clipping)', fontsize = 25)
plt.savefig('1D-J1-J2-N=50-gc.png')
# Out:
# /var/folders/cj/1sxs7wzx40l7609nvj0b33c40000gn/T/ipykernel_2126/2159504678.py:21: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.savefig('1D-J1-J2-N=50-gc.png')
# /opt/anaconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
color_l = ['cyan', 'green']
fig, ax = plt.subplots(2,2, figsize=(10, 10), tight_layout=True)

e_list00 = [vE00_75_o, vEh00_60_o]
e_names00 = ['eGRU_75_s50_o', 'hGRU_60_s50_o']
e_list02 = [vE02_75_o, vEh02_75_o]
e_names02 = ['eGRU_75_s50_o', 'hGRU_75_s50_o']
e_list05 = [vE05_75_o, vEh05_70_o]
e_names05 = ['eGRU_75_s50_o', 'hGRU_70_s50_o']
e_list08 = [vE08_75_o, vEh08_75_o]
e_names08 = ['eGRU_75_s50_o', 'hGRU_75_s50_o']

plot_res_var(ax[0,0], e_list00, e_names00, 0.0, [300,460, -0.5, 4.5], (0.15, 0.75, 0.3, 0.2))
plot_res_var(ax[0,1], e_list02, e_names02, 0.2, [300,460, -0.2, 2.], (0.15, 0.75, 0.3, 0.2))
plot_res_var(ax[1,0], e_list05, e_names05, 0.5, [200,420,-0.5, 4.5], (0.15, 0.75, 0.3, 0.2))
plot_res_var(ax[1,1], e_list08, e_names08, 0.8, [200,420,-0.5, 5], (0.15, 0.75, 0.3, 0.2))

plt.suptitle('1D J1-J2: Variance Convergence (no gradient clipping)', fontsize = 23)
plt.savefig('1D-J1-J2-N=50-var.png')

# %%
color_l = ['orange', 'purple']
fig, ax = plt.subplots(2,2, figsize=(10, 10), tight_layout=True)

e_list00 = [vE00_75, vEh00_60]
e_names00 = ['eGRU_75_s50', 'hGRU_60_s50']
e_list02 = [vE02_75, vEh02_75]
e_names02 = ['eGRU_75_s50', 'hGRU_75_s50']
e_list05 = [vE05_75, vEh05_70]
e_names05 = ['eGRU_75_s50', 'hGRU_70_s50_o']
e_list08 = [vE08_75, vEh08_75]
e_names08 = ['eGRU_75_s50', 'hGRU_75_s50']

plot_res_var(ax[0,0], e_list00, e_names00, 0.0, [300,460, -0.5, 4.5], (0.15, 0.75, 0.3, 0.2))
plot_res_var(ax[0,1], e_list02, e_names02, 0.2, [300,460, -0.2, 2.], (0.15, 0.75, 0.3, 0.2))
plot_res_var(ax[1,0], e_list05, e_names05, 0.5, [200,420,-0.5, 4.5], (0.15, 0.75, 0.3, 0.2))
plot_res_var(ax[1,1], e_list08, e_names08, 0.8, [200,420,-0.5, 5], (0.15, 0.75, 0.3, 0.2))

plt.suptitle('1D J1-J2: Variance Convergence (with gradient clipping)', fontsize = 23)
plt.savefig('1D-J1-J2-N=50-var-gc.png')

# %%
def plot_res_meanE_c(ax, Ee, e_list,  e_names, j2, frange, legend_loc, inset = False):
    for i in range(len(e_list)):
        ax.plot(np.arange(len(e_list[i])), np.real(e_list[i]),color = color_l[i], label = e_names[i])
    ax.axhline(Ee, color = 'red', linestyle = 'dashed', label = 'DMRG')
    ax.set_xlabel("Epoch", fontsize = 14)
    ax.set_ylabel("Mean Energy", fontsize = 14)
    ax.set_title(f"J2={j2}",fontsize = 15)
    
    if inset:
        ax2 = inset_axes(
                parent_axes=ax,
                width="45%",
                height="35%",
                borderpad=1  # padding between parent and inset axes
            )
        for i in range(len(e_list)):
            ax2.plot(np.arange(len(e_list[i])), np.real(e_list[i]),color = color_l[i], label = e_names[i])
        ax2.axhline(Ee, color = 'red', linestyle = 'dashed', label = 'DMRG')
        ax2.axis(frange)
        ax.legend(loc='best', bbox_to_anchor=legend_loc)
    else:
        ax.legend(loc='best')

# %%
#EUCLIDEAN RNN WITH AND WITHOUT GRADIENT CLIPPING
color_l = ['cyan',  'orange']
fig, ax = plt.subplots(2,2, figsize=(10, 10), tight_layout=True)
e_list00 = [mE00_75_o,  mE00_75]
e_names00 = ['eGRU_75_s50_o', 'eGRU_75_s50']

e_list02 = [mE02_75_o,  mE02_75]
e_names02 = ['eGRU_75_s50_o', 'eGRU_75_s50']

e_list05 = [mE05_75_o[:-5], mE05_75]
e_names05 = ['eGRU_75_s50_o',  'eGRU_75_s50']

e_list08 = [mE08_75_o, mE08_75]
e_names08 = ['eGRU_75_s50_o','eGRU_75_s50']

plot_res_meanE_c(ax[0,0], Ee00, e_list00, e_names00, 0.0, [200,460, Ee00-0.5, Ee00+3.5], (0.15, 0.28, 0.8, 0.2))
plot_res_meanE_c(ax[0,1], Ee02, e_list02, e_names02, 0.2, [200,460, Ee02-0.2, Ee02+1.5], (0.15, 0.28, 0.8, 0.2))
plot_res_meanE_c(ax[1,0], Ee05, e_list05, e_names05, 0.5, [200,460,Ee05-0.2, Ee05+0.7], (0.15, 0.3, 0.8, 0.2))
plot_res_meanE_c(ax[1,1], Ee08, e_list08, e_names08, 0.8, [250,460,Ee08-0.5, Ee08+4.5], (0.15, 0.3, 0.8, 0.2))

plt.suptitle('1D J1-J2: Mean Energy Convergence (Euclidean NQS only)', fontsize = 23)
plt.savefig('1D-J1-J2-N=50_eRNN-w-wo-gc.png')

# %%
#HYPERBOLIC RNN WITH AND WITHOUT GRADIENT CLIPPING
color_l = ['green',  'purple']
fig, ax = plt.subplots(2,2, figsize=(10, 10), tight_layout=True)
e_list00 = [mEh00_60_o,  mEh00_60]
e_names00 = ['hGRU_60_s50_o', 'hGRU_60_s50']

e_list02 = [mEh02_75_o, mEh02_75]
e_names02 = ['hGRU_75_s50_o', 'hGRU_75_s50']

e_list05 = [mEh05_70]
e_names05 = ['hGRU_70_s50']

e_list08 = [mEh08_75_o[:-5], mEh08_75]
e_names08 = ['hGRU_75_s50_o','hGRU_75_s50']

plot_res_meanE_c(ax[0,0], Ee00, e_list00, e_names00, 0.0, [200,460, Ee00-0.5, Ee00+3.5], (0.15, 0.28, 0.8, 0.2), True)
plot_res_meanE_c(ax[0,1], Ee02, e_list02, e_names02, 0.2, [200,460, Ee02-0.2, Ee02+1.5], (0.15, 0.28, 0.8, 0.2), True)
plot_res_meanE_c(ax[1,0], Ee05, e_list05, e_names05, 0.5, [200,460,Ee05-0.2, Ee05+0.7], (0.15, 0.3, 0.8, 0.2), True)
plot_res_meanE_c(ax[1,1], Ee08, e_list08, e_names08, 0.8, [250,460,Ee08-0.5, Ee08+4.5], (0.15, 0.3, 0.8, 0.2),True)

plt.suptitle('1D J1-J2: Mean Energy Convergence (Hyperbolic NQS only)', fontsize = 23)
plt.savefig('1D-J1-J2-N=50_hRNN-w-wo-gc.png')
# Out:
# /var/folders/cj/1sxs7wzx40l7609nvj0b33c40000gn/T/ipykernel_2126/3918952098.py:22: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.savefig('1D-J1-J2-N=50_hRNN-w-wo-gc.png')
