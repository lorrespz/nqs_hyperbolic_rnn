# %%
import numpy as np 
import matplotlib.pyplot as plt

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/nqs-rnn/rnn_impl_tf2.py
# /kaggle/input/nqs-rnn/nqs_TrainingLoop_hyp_tf2.py
# /kaggle/input/nqs-rnn/util_v2.py
# /kaggle/input/nqs-rnn/nqs_RNNwavefunction_hyp.py

# %%
#https://www.kaggle.com/discussions/product-feedback/91185
import sys
sys.path.insert(1,'/kaggle/input/nqs-rnn/')
from nqs_TrainingLoop_hyp_tf2 import *

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
N=40
numunits = 50
Jz = np.ones(N)
Bx = 1
E_exact = -50.5694337844

# %%
if not os.path.exists('/kaggle/working/results'):
    os.mkdir('/kaggle/working/results')

# %%
#HypRNN
#mE_hrnn, vE_hrnn = run_1DTFIM(numsteps = 200,cell_type = 'HypRNN', systemsize = N, num_units = numunits, 
#                              Bx = Bx, numsamples = 500, learningrate=1e-2, seed = 111)

# %%
#HypGRU
#mE_hgru, vE_hgru = run_1DTFIM(numsteps = 200,cell_type = 'HypGRU', systemsize = N, num_units = numunits, Bx = Bx, 
#                numsamples = 500, learningrate=1e-2, seed = 111)

# %%
#EuclGRU
mE_egru, vE_egru = run_1DTFIM(numsteps = 200,cell_type = 'EuclGRU', systemsize = N, num_units = numunits, Bx = Bx, 
                numsamples = 500, learningrate=1e-2, seed = 111)
# Out:
# step: 0, loss: -0.5523866371952408, mean energy: -40.18394355708491, varE: 35.76736131719724
# step: 10, loss: -1.5840209043476534, mean energy: -50.22487656415158, varE: 0.786925728167308
# step: 20, loss: 0.7454006129958088, mean energy: -50.45567879231539, varE: 0.34064582279030664
# step: 30, loss: 0.0451544059602611, mean energy: -50.48223676838174, varE: 0.4056822474661116
# step: 40, loss: 0.18111150199410986, mean energy: -50.47186363326737, varE: 0.2273788945625251
# step: 50, loss: 0.001883879156821422, mean energy: -50.48985974994022, varE: 0.2631686449186549
# step: 60, loss: -0.07838369183059513, mean energy: -50.517623691057565, varE: 0.16021005133692404
# step: 70, loss: -0.06030899858137673, mean energy: -50.50709649351152, varE: 0.16228349718164234
# step: 80, loss: 0.00014963362787057122, mean energy: -50.5255812318407, varE: 0.10081885256741398
# step: 90, loss: -0.10559314059423741, mean energy: -50.51076861635044, varE: 0.088997239519181
# step: 100, loss: 0.004120293907590167, mean energy: -50.56046922733486, varE: 0.08338583220898005
# step: 110, loss: 0.07770710662350666, mean energy: -50.55981506426494, varE: 0.07917092447623744
# step: 130, loss: -0.12247529055275663, mean energy: -50.54615909050394, varE: 0.06202049064430555
# step: 140, loss: -0.04346034015782152, mean energy: -50.52701590693604, varE: 0.05607150120259543
